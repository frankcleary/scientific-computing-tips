# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("../input/speeds.csv", ) # output a pandas data frame
data.head(10)
# Out:
#         208       12GS      24GS       48GS
# 0  186.7092  211.53480   14.0937  107.44830
# 1  184.3860  211.53480  226.2750   93.09600
# 2  181.0200  211.53480   18.6192  121.87818
# 3  180.5940  193.95000  145.4625  120.71448
# 4  180.5940  191.81200    8.9217   90.53586
# 5  172.4862  188.00220  145.4625  135.76500
# 6  172.4862  186.75600  136.9287  174.55500
# 7  172.4862  184.40136  232.7400  133.59276
# 8  172.4862  182.57160  147.7899  100.85400
# 9  172.4862  175.53800  141.0663  155.16000

# %%
data.mean()
# Out:
# 208      96.627807
# 12GS     95.138958
# 24GS    128.207107
# 48GS    110.515913
# dtype: float64

# %%
data.hist()
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x0000000008A28B38>,
#         <matplotlib.axes.AxesSubplot object at 0x0000000008AEE630>],
#        [<matplotlib.axes.AxesSubplot object at 0x0000000008C43438>,
#         <matplotlib.axes.AxesSubplot object at 0x0000000008C60240>]], dtype=object)

# %%
data.hist(bins=range(0, 300, 20), color='k', alpha=0.5)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x0000000008C4C860>,
#         <matplotlib.axes.AxesSubplot object at 0x000000000A33B198>],
#        [<matplotlib.axes.AxesSubplot object at 0x000000000A532828>,
#         <matplotlib.axes.AxesSubplot object at 0x000000000A54FBA8>]], dtype=object)

# %%
data.hist(bins=50, color='k', alpha=0.5,
          grid=True, sharex=True, layout=(4, 1), figsize=(4,6))
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x000000000AC77E10>],
#        [<matplotlib.axes.AxesSubplot object at 0x000000000B3C4320>],
#        [<matplotlib.axes.AxesSubplot object at 0x000000000B2AB908>],
#        [<matplotlib.axes.AxesSubplot object at 0x000000000B2C7EF0>]], dtype=object)

# %%
data.mean()
# Out:
# 208      96.627807
# 12GS     95.138958
# 24GS    128.207107
# 48GS    110.515913
# dtype: float64

# %%
data.mean().plot(kind='bar', color='k', alpha=0.5)

# %% [markdown]
# ### GS Speed Data:

# %%
data.mean().plot(kind='bar', color='k', alpha=0.5, yerr=data.std(), ecolor='k')

# %% [markdown]
# Here I'll add a comment descirbing the t-test I'm doing below:

# %%
from scipy.stats import ttest_ind
ttest_ind(data['208'], data['24GS'][~np.isnan(data['24GS'])], equal_var=False)

# %%
dataseries = {col : data[col] for col in data.columns}

# %%
data.columns
